# %% [markdown]
# ### Image Cleaning
# > We want to prepare our images to have the same shape. For this task im going to create 2 folders of gray images and colored images of the same shape.

# %%
import os, cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
class Images:
    GRAY_IMAGES_BEES = "data/gray/bees"
    GRAY_IMAGES_ANTS = "data/gray/ants"
    COLORED_IMAGES_ANTS_RGB = 'data/colored/rgb/ants'
    COLORED_IMAGES_BEES_RGB = "data/colored/rgb/bees"
    COLORED_IMAGES_ANTS_BGR = 'data/colored/bgr/ants'
    COLORED_IMAGES_BEES_BGR = "data/colored/bgr/bees"
    BEES_PATH = 'data/bees_raw'
    ANTS_PATH = 'data/ants_raw'

# %%
def convert(path, gray, colored_rgb, colored_bgr):
    paths = os.listdir(path)
    for p in paths:
        image = cv2.imread(os.path.join(path, p))
        image = cv2.resize(image, (200, 200))
        image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        if not os.path.exists(gray):
            os.makedirs(gray)
        if not os.path.exists(colored_rgb):
            os.makedirs(colored_rgb)
        if not os.path.exists(colored_bgr):
            os.makedirs(colored_bgr)
        print("Writting image: ", p)
        cv2.imwrite(os.path.join(gray,p), image_gray)
        cv2.imwrite(os.path.join(colored_rgb,p), image_rgb)
        cv2.imwrite(os.path.join(colored_bgr,p), image)
convert(Images.BEES_PATH, Images.GRAY_IMAGES_BEES, Images.COLORED_IMAGES_BEES_RGB, Images.COLORED_IMAGES_BEES_BGR)
convert(Images.ANTS_PATH, Images.GRAY_IMAGES_ANTS, Images.COLORED_IMAGES_ANTS_RGB, Images.COLORED_IMAGES_ANTS_BGR)
# Out:
# Writting image:  bee1.png
# Writting image:  bee10.png
# Writting image:  bee100.png
# Writting image:  bee101.png
# Writting image:  bee102.png
# Writting image:  bee103.png
# Writting image:  bee104.png
# Writting image:  bee105.png
# Writting image:  bee106.png
# Writting image:  bee107.png
# Writting image:  bee108.png
# Writting image:  bee109.png
# Writting image:  bee11.png
# Writting image:  bee110.png
# Writting image:  bee111.png
# Writting image:  bee112.png
# Writting image:  bee113.png
# Writting image:  bee114.png
# Writting image:  bee115.png
# Writting image:  bee116.png
# Writting image:  bee117.png
# Writting image:  bee118.png
# Writting image:  bee119.png
# Writting image:  bee12.png
# Writting image:  bee120.png
# Writting image:  bee121.png
# Writting image:  bee122.png
# Writting image:  bee123.png
# Writting image:  bee124.png
# Writting image:  bee125.png
# Writting image:  bee126.png
# Writting image:  bee127.png
# Writting image:  bee128.png
# Writting image:  bee129.png
# Writting image:  bee13.png
# Writting image:  bee130.png
# Writting image:  bee131.png
# Writting image:  bee132.png
# Writting image:  bee133.png
# Writting image:  bee134.png
# Writting image:  bee135.png
# Writting image:  bee136.png
# Writting image:  bee137.png
# Writting image:  bee138.png
# Writting image:  bee139.png
# Writting image:  bee14.png
# Writting image:  bee140.png
# Writting image:  bee141.png
# Writting image:  bee142.png
# Writting image:  bee143.png
# Writting image:  bee144.png
# Writting image:  bee145.png
# Writting image:  bee146.png
# Writting image:  bee147.png
# Writting image:  bee148.png
# Writting image:  bee149.png
# Writting image:  bee15.png
# Writting image:  bee150.png
# Writting image:  bee151.png
# Writting image:  bee152.png
# Writting image:  bee153.png
# Writting image:  bee154.png
# Writting image:  bee155.png
# Writting image:  bee156.png
# Writting image:  bee157.png
# Writting image:  bee158.png
# Writting image:  bee159.png
# Writting image:  bee16.png
# Writting image:  bee160.png
# Writting image:  bee161.png
# Writting image:  bee162.png
# Writting image:  bee163.png
# Writting image:  bee164.png
# Writting image:  bee165.png
# Writting image:  bee166.png
# Writting image:  bee167.png
# Writting image:  bee168.png
# Writting image:  bee169.png
# Writting image:  bee17.png
# Writting image:  bee170.png
# Writting image:  bee171.png
# Writting image:  bee172.png
# Writting image:  bee173.png
# Writting image:  bee174.png
# Writting image:  bee175.png
# Writting image:  bee176.png
# Writting image:  bee177.png
# Writting image:  bee178.png
# Writting image:  bee179.png
# Writting image:  bee18.png
# Writting image:  bee180.png
# Writting image:  bee181.png
# Writting image:  bee182.png
# Writting image:  bee183.png
# Writting image:  bee184.png
# Writting image:  bee185.png
# Writting image:  bee186.png
# Writting image:  bee187.png
# Writting image:  bee188.png
# Writting image:  bee189.png
# Writting image:  bee19.png
# Writting image:  bee190.png
# Writting image:  bee191.png
# Writting image:  bee192.png
# Writting image:  bee193.png
# Writting image:  bee194.png
# Writting image:  bee195.png
# Writting image:  bee196.png
# Writting image:  bee197.png
# Writting image:  bee198.png
# Writting image:  bee199.png
# Writting image:  bee2.png
# Writting image:  bee20.png
# Writting image:  bee200.png
# Writting image:  bee201.png
# Writting image:  bee202.png
# Writting image:  bee203.png
# Writting image:  bee204.png
# Writting image:  bee205.png
# Writting image:  bee206.png
# Writting image:  bee207.png
# Writting image:  bee208.png
# Writting image:  bee209.png
# Writting image:  bee21.png
# Writting image:  bee210.png
# Writting image:  bee211.png
# Writting image:  bee212.png
# Writting image:  bee213.png
# Writting image:  bee214.png
# Writting image:  bee215.png
# Writting image:  bee216.png
# Writting image:  bee217.png
# Writting image:  bee218.png
# Writting image:  bee219.png
# Writting image:  bee22.png
# Writting image:  bee220.png
# Writting image:  bee221.png
# Writting image:  bee222.png
# Writting image:  bee223.png
# Writting image:  bee224.png
# Writting image:  bee225.png
# Writting image:  bee226.png
# Writting image:  bee227.png
# Writting image:  bee228.png
# Writting image:  bee229.png
# Writting image:  bee23.png
# Writting image:  bee230.png
# Writting image:  bee231.png
# Writting image:  bee232.png
# Writting image:  bee233.png
# Writting image:  bee234.png
# Writting image:  bee235.png
# Writting image:  bee236.png
# Writting image:  bee237.png
# Writting image:  bee238.png
# Writting image:  bee239.png
# Writting image:  bee24.png
# Writting image:  bee240.png
# Writting image:  bee25.png
# Writting image:  bee26.png
# Writting image:  bee27.png
# Writting image:  bee28.png
# Writting image:  bee29.png
# Writting image:  bee3.png
# Writting image:  bee30.png
# Writting image:  bee31.png
# Writting image:  bee32.png
# Writting image:  bee33.png
# Writting image:  bee34.png
# Writting image:  bee35.png
# Writting image:  bee36.png
# Writting image:  bee37.png
# Writting image:  bee38.png
# Writting image:  bee39.png
# Writting image:  bee4.png
# Writting image:  bee40.png
# Writting image:  bee41.png
# Writting image:  bee42.png
# Writting image:  bee43.png
# Writting image:  bee44.png
# Writting image:  bee45.png
# Writting image:  bee46.png
# Writting image:  bee47.png
# Writting image:  bee48.png
# Writting image:  bee49.png
# Writting image:  bee5.png
# Writting image:  bee50.png
# Writting image:  bee51.png
# Writting image:  bee52.png
# Writting image:  bee53.png
# Writting image:  bee54.png
# Writting image:  bee55.png
# Writting image:  bee56.png
# Writting image:  bee57.png
# Writting image:  bee58.png
# Writting image:  bee59.png
# Writting image:  bee6.png
# Writting image:  bee60.png
# Writting image:  bee61.png
# Writting image:  bee62.png
# Writting image:  bee63.png
# Writting image:  bee64.png
# Writting image:  bee65.png
# Writting image:  bee66.png
# Writting image:  bee67.png
# Writting image:  bee68.png
# Writting image:  bee69.png
# Writting image:  bee7.png
# Writting image:  bee70.png
# Writting image:  bee71.png
# Writting image:  bee72.png
# Writting image:  bee73.png
# Writting image:  bee74.png
# Writting image:  bee75.png
# Writting image:  bee76.png
# Writting image:  bee77.png
# Writting image:  bee78.png
# Writting image:  bee79.png
# Writting image:  bee8.png
# Writting image:  bee80.png
# Writting image:  bee81.png
# Writting image:  bee82.png
# Writting image:  bee83.png
# Writting image:  bee84.png
# Writting image:  bee85.png
# Writting image:  bee86.png
# Writting image:  bee87.png
# Writting image:  bee88.png
# Writting image:  bee89.png
# Writting image:  bee9.png
# Writting image:  bee90.png
# Writting image:  bee91.png
# Writting image:  bee92.png
# Writting image:  bee93.png
# Writting image:  bee94.png
# Writting image:  bee95.png
# Writting image:  bee96.png
# Writting image:  bee97.png
# Writting image:  bee98.png
# Writting image:  bee99.png
# Writting image:  ant1.png
# Writting image:  ant10.png
# Writting image:  ant100.png
# Writting image:  ant101.png
# Writting image:  ant102.png
# Writting image:  ant103.png
# Writting image:  ant104.png
# Writting image:  ant105.png
# Writting image:  ant106.png
# Writting image:  ant107.png
# Writting image:  ant108.png
# Writting image:  ant109.png
# Writting image:  ant11.png
# Writting image:  ant110.png
# Writting image:  ant111.png
# Writting image:  ant112.png
# Writting image:  ant113.png
# Writting image:  ant114.png
# Writting image:  ant115.png
# Writting image:  ant116.png
# Writting image:  ant117.png
# Writting image:  ant118.png
# Writting image:  ant119.png
# Writting image:  ant12.png
# Writting image:  ant120.png
# Writting image:  ant121.png
# Writting image:  ant122.png
# Writting image:  ant123.png
# Writting image:  ant124.png
# Writting image:  ant125.png
# Writting image:  ant126.png
# Writting image:  ant127.png
# Writting image:  ant128.png
# Writting image:  ant129.png
# Writting image:  ant13.png
# Writting image:  ant130.png
# Writting image:  ant131.png
# Writting image:  ant132.png
# Writting image:  ant133.png
# Writting image:  ant134.png
# Writting image:  ant135.png
# Writting image:  ant136.png
# Writting image:  ant137.png
# Writting image:  ant138.png
# Writting image:  ant139.png
# Writting image:  ant14.png
# Writting image:  ant140.png
# Writting image:  ant141.png
# Writting image:  ant142.png
# Writting image:  ant143.png
# Writting image:  ant144.png
# Writting image:  ant145.png
# Writting image:  ant146.png
# Writting image:  ant147.png
# Writting image:  ant148.png
# Writting image:  ant149.png
# Writting image:  ant15.png
# Writting image:  ant150.png
# Writting image:  ant151.png
# Writting image:  ant152.png
# Writting image:  ant153.png
# Writting image:  ant154.png
# Writting image:  ant155.png
# Writting image:  ant156.png
# Writting image:  ant157.png
# Writting image:  ant158.png
# Writting image:  ant159.png
# Writting image:  ant16.png
# Writting image:  ant160.png
# Writting image:  ant161.png
# Writting image:  ant162.png
# Writting image:  ant163.png
# Writting image:  ant164.png
# Writting image:  ant165.png
# Writting image:  ant166.png
# Writting image:  ant167.png
# Writting image:  ant168.png
# Writting image:  ant169.png
# Writting image:  ant17.png
# Writting image:  ant170.png
# Writting image:  ant171.png
# Writting image:  ant172.png
# Writting image:  ant173.png
# Writting image:  ant174.png
# Writting image:  ant175.png
# Writting image:  ant176.png
# Writting image:  ant177.png
# Writting image:  ant178.png
# Writting image:  ant179.png
# Writting image:  ant18.png
# Writting image:  ant180.png
# Writting image:  ant181.png
# Writting image:  ant182.png
# Writting image:  ant183.png
# Writting image:  ant184.png
# Writting image:  ant185.png
# Writting image:  ant186.png
# Writting image:  ant187.png
# Writting image:  ant188.png
# Writting image:  ant189.png
# Writting image:  ant19.png
# Writting image:  ant190.png
# Writting image:  ant191.png
# Writting image:  ant192.png
# Writting image:  ant193.png
# Writting image:  ant194.png
# Writting image:  ant195.png
# Writting image:  ant196.png
# Writting image:  ant197.png
# Writting image:  ant198.png
# Writting image:  ant199.png
# Writting image:  ant2.png
# Writting image:  ant20.png
# Writting image:  ant200.png
# Writting image:  ant201.png
# Writting image:  ant202.png
# Writting image:  ant203.png
# Writting image:  ant204.png
# Writting image:  ant205.png
# Writting image:  ant206.png
# Writting image:  ant207.png
# Writting image:  ant208.png
# Writting image:  ant209.png
# Writting image:  ant21.png
# Writting image:  ant210.png
# Writting image:  ant211.png
# Writting image:  ant212.png
# Writting image:  ant213.png
# Writting image:  ant214.png
# Writting image:  ant215.png
# Writting image:  ant216.png
# Writting image:  ant217.png
# Writting image:  ant218.png
# Writting image:  ant219.png
# Writting image:  ant22.png
# Writting image:  ant220.png
# Writting image:  ant221.png
# Writting image:  ant222.png
# Writting image:  ant223.png
# Writting image:  ant224.png
# Writting image:  ant225.png
# Writting image:  ant226.png
# Writting image:  ant227.png
# Writting image:  ant228.png
# Writting image:  ant229.png
# Writting image:  ant23.png
# Writting image:  ant230.png
# Writting image:  ant231.png
# Writting image:  ant232.png
# Writting image:  ant233.png
# Writting image:  ant234.png
# Writting image:  ant235.png
# Writting image:  ant236.png
# Writting image:  ant237.png
# Writting image:  ant238.png
# Writting image:  ant239.png
# Writting image:  ant24.png
# Writting image:  ant240.png
# Writting image:  ant25.png
# Writting image:  ant26.png
# Writting image:  ant27.png
# Writting image:  ant28.png
# Writting image:  ant29.png
# Writting image:  ant3.png
# Writting image:  ant30.png
# Writting image:  ant31.png
# Writting image:  ant32.png
# Writting image:  ant33.png
# Writting image:  ant34.png
# Writting image:  ant35.png
# Writting image:  ant36.png
# Writting image:  ant37.png
# Writting image:  ant38.png
# Writting image:  ant39.png
# Writting image:  ant4.png
# Writting image:  ant40.png
# Writting image:  ant41.png
# Writting image:  ant42.png
# Writting image:  ant43.png
# Writting image:  ant44.png
# Writting image:  ant45.png
# Writting image:  ant46.png
# Writting image:  ant47.png
# Writting image:  ant48.png
# Writting image:  ant49.png
# Writting image:  ant5.png
# Writting image:  ant50.png
# Writting image:  ant51.png
# Writting image:  ant52.png
# Writting image:  ant53.png
# Writting image:  ant54.png
# Writting image:  ant55.png
# Writting image:  ant56.png
# Writting image:  ant57.png
# Writting image:  ant58.png
# Writting image:  ant59.png
# Writting image:  ant6.png
# Writting image:  ant60.png
# Writting image:  ant61.png
# Writting image:  ant62.png
# Writting image:  ant63.png
# Writting image:  ant64.png
# Writting image:  ant65.png
# Writting image:  ant66.png
# Writting image:  ant67.png
# Writting image:  ant68.png
# Writting image:  ant69.png
# Writting image:  ant7.png
# Writting image:  ant70.png
# Writting image:  ant71.png
# Writting image:  ant72.png
# Writting image:  ant73.png
# Writting image:  ant74.png
# Writting image:  ant75.png
# Writting image:  ant76.png
# Writting image:  ant77.png
# Writting image:  ant78.png
# Writting image:  ant79.png
# Writting image:  ant8.png
# Writting image:  ant80.png
# Writting image:  ant81.png
# Writting image:  ant82.png
# Writting image:  ant83.png
# Writting image:  ant84.png
# Writting image:  ant85.png
# Writting image:  ant86.png
# Writting image:  ant87.png
# Writting image:  ant88.png
# Writting image:  ant89.png
# Writting image:  ant9.png
# Writting image:  ant90.png
# Writting image:  ant91.png
# Writting image:  ant92.png
# Writting image:  ant93.png
# Writting image:  ant94.png
# Writting image:  ant95.png
# Writting image:  ant96.png
# Writting image:  ant97.png
# Writting image:  ant98.png
# Writting image:  ant99.png

# %% [markdown]
# > Image Cleaning done!
